# %%
import matplotlib.pyplot as plt
from experiments.distributions.retrain_distribution import normal_retrain_layer_dist_50, normal_retrain_layer_dist_25, normal_retrain_layer_dist_last_few

# %%
num_layers = 40
num_models = 10000
numbers = normal_retrain_layer_dist_50(num_layers, num_models)
plt.hist(numbers, bins=range(0, 40), edgecolor='black', alpha=0.7)
plt.xticks(range(0, 40, 2))
plt.grid(axis='y')
plt.show()

# %%
num_layers = 40
num_models = 10000
numbers = normal_retrain_layer_dist_25(num_layers, num_models)
plt.hist(numbers, bins=range(0, 40), edgecolor='black', alpha=0.7)
plt.xticks(range(0, 40, 2))
plt.grid(axis='y')
plt.show()

# %%
num_layers = 40
num_models = 10000
numbers = normal_retrain_layer_dist_last_few(num_layers, num_models)
plt.hist(numbers, bins=range(0, 40), edgecolor='black', alpha=0.7)
plt.xticks(range(0, 40, 2))
plt.grid(axis='y')
plt.show()
